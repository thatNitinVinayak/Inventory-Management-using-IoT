# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
items=pd.read_csv('E:/final year project/items.csv')

# %%
items.head()
# Out:
#                      id  prices.amountMax  prices.amountMin  \
# 0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4  AVpgMuGwLJeJML43KY_c             66.99             66.99
#
#   prices.availability prices.condition prices.currency  \
# 0                 Yes              New             USD
# 1            In Stock              New             USD
# 2            In Stock              New             USD
# 3                 Yes              New             USD
# 4                 Yes              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                               2017-12-14T06:00:00Z           True
# ...

# %%
items.shape
# Out:
# (14592, 31)

# %%
items=items[['id','name','brand','categories','primaryCategories','prices.amountMin']]

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#      brand                                         categories  \
# 0    Sanus  Audio & Video Accessories,TV Mounts,TV Accesso...
# 1  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...
# 2  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...
# 3  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...
# 4  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...
#
#   primaryCategories  prices.amountMin
# 0       Electronics            104.99
# 1       Electronics             64.99
# ...

# %%
items.columns=['id','name','brand','category','product','price']
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#        brand                                           category  \
# 0    [Sanus]  [Audio, &, Video, Accessories,TV, Mounts,TV, A...
# 1  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 2  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 3  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 4  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
#
#          product   price
# 0  [Electronics]  104.99
# 1  [Electronics]   64.99
# 2  [Electronics]   69.00
# ...

# %%
items['price'] = items['price'].apply(lambda x:x.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5664/2460389789.py in <module>
# ----> 1 items['price'] = items['price'].apply(lambda x:x.split())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# ...

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  [Sanus, VLF410B1, 10-Inch, Super, Slim, Full-M...
# 1  AVpgMuGwLJeJML43KY_c  [Boytone, -, 2500W, 2.1-Ch., Home, Theater, Sy...
# 2  AVpgMuGwLJeJML43KY_c  [Boytone, -, 2500W, 2.1-Ch., Home, Theater, Sy...
# 3  AVpgMuGwLJeJML43KY_c  [Boytone, -, 2500W, 2.1-Ch., Home, Theater, Sy...
# 4  AVpgMuGwLJeJML43KY_c  [Boytone, -, 2500W, 2.1-Ch., Home, Theater, Sy...
#
#      brand                                           category      product  \
# 0    Sanus  Audio & Video Accessories,TV Mounts,TV Accesso...  Electronics
# 1  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 2  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 3  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 4  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
#
#     price
# 0  104.99
# 1   64.99
# 2   69.00
# 3   69.99
# ...

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#      brand                                           category      product  \
# 0    Sanus  Audio & Video Accessories,TV Mounts,TV Accesso...  Electronics
# 1  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 2  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 3  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
# 4  Boytone  Stereos,Portable Bluetooth Speakers,TV, Video ...  Electronics
#
#     price
# 0  104.99
# 1   64.99
# 2   69.00
# 3   69.99
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
#Using The min-max feature scaling:
df_min_max_scaled = items.copy()
  
# apply normalization techniques by Column 1
column = 'price'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
display(df_min_max_scaled)
# Out:
#                          id  \
# 0      AVphzgbJLJeJML43fA0o
# 1      AVpgMuGwLJeJML43KY_c
# 2      AVpgMuGwLJeJML43KY_c
# 3      AVpgMuGwLJeJML43KY_c
# 4      AVpgMuGwLJeJML43KY_c
# ...                     ...
# 14587  AVpgibRDLJeJML43PTZX
# 14588  AVpgibRDLJeJML43PTZX
# 14589  AVpgibRDLJeJML43PTZX
# 14590  AVpgibRDLJeJML43PTZX
# 14591  AVpgibRDLJeJML43PTZX
#
#                                                     name      brand  \
# 0      Sanus VLF410B1 10-Inch Super Slim Full-Motion ...    [Sanus]
# 1      Boytone - 2500W 2.1-Ch. Home Theater System - ...  [Boytone]
# 2      Boytone - 2500W 2.1-Ch. Home Theater System - ...  [Boytone]
# 3      Boytone - 2500W 2.1-Ch. Home Theater System - ...  [Boytone]
# 4      Boytone - 2500W 2.1-Ch. Home Theater System - ...  [Boytone]
# ...                                                  ...        ...
# 14587  naxa - 2.1-Channel Soundbar with 50-Watt Digit...     [naxa]
# 14588  naxa - 2.1-Channel Soundbar with 50-Watt Digit...     [naxa]
# ...

# %%
 items=df_min_max_scaled.copy()

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#        brand                                           category  \
# 0    [Sanus]  [Audio, &, Video, Accessories,TV, Mounts,TV, A...
# 1  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 2  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 3  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 4  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
#
#          product     price
# 0  [Electronics]  0.003870
# 1  [Electronics]  0.002381
# 2  [Electronics]  0.002531
# ...

# %%
items['tags']=items['brand']+items['category']+items['product']

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#        brand                                           category  \
# 0    [Sanus]  [Audio, &, Video, Accessories,TV, Mounts,TV, A...
# 1  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 2  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 3  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
# 4  [Boytone]  [Stereos,Portable, Bluetooth, Speakers,TV,, Vi...
#
#          product     price                                               tags
# ...

# %%
items=items.drop(columns=['brand','category','product','price'])

# %%
items.head()
# Out:
#                      id                                               name  \
# 0  AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4  AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#                                                 tags
# 0  [Sanus, Audio, &, Video, Accessories,TV, Mount...
# 1  [Boytone, Stereos,Portable, Bluetooth, Speaker...
# 2  [Boytone, Stereos,Portable, Bluetooth, Speaker...
# 3  [Boytone, Stereos,Portable, Bluetooth, Speaker...
# 4  [Boytone, Stereos,Portable, Bluetooth, Speaker...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')
items['tags'] = items['tags'].apply(lambda x: " ".join(x))

# %%
vector = cv.fit_transform(items['tags']).toarray()

# %%
vector.shape
# Out:
# (14592, 1976)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity[0]
# Out:
# array([1.        , 0.28254545, 0.28254545, ..., 0.29450754, 0.29450754,
#        0.29450754])

# %%
items[items['name']=='UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player'].index[0]
# Out:
# 613

# %%
def recommend(item):
    index = items[items['name'] == item].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(items.iloc[i[0]].name)

# %%
recommend('UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player')
# Out:
# 614
# 615
# 616
# 617
# 618

# %%
items['name'].iloc[789]
# Out:
# 'Hoya - EVO 77mm Antistatic UV Super Multicoated Lens Filter - Gray'
